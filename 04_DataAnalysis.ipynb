# %% [markdown]
# # Analysis

# %%
import pandas as pd

# %%
df = pd.read_pickle("./data/df_merge_club_transfer_data_prep1.pkl")
df.columns
# Out:
# Index(['DATE', 'WEEKDAY', 'MONTH', 'SEASON', 'MATCHDAY', 'HOME_TEAM',
#        'PLACE_HOME_TEAM', 'AWAY_TEAM', 'PLACE_AWAY_TEAM', 'WIN_PERC_HOME',
#        'REMIS_PERC', 'WIN_PERC_AWAY', 'HOME_GOALS', 'AWAY_GOALS', 'RESULT',
#        'REFEREE', 'HOME_PLAYERS_COUNT', 'HOME_PLAYERS_AVG_AGE',
#        'HOME_LEGIONARIES_COUNT', 'HOME_AVG_MARKET_VALUE',
#        'HOME_TOTAL_MARKET_VALUE', 'HOME_AVG_AGE_JOINING',
#        'HOME_AVG_AGE_LEAVING', 'HOME_TOTAL_VALUE_JOINING_MIO',
#        'HOME_TOTAL_VALUE_LEAVING_MIO', 'HOME_EXPENSES_JOINING_MIO',
#        'HOME_REVENUE_LEAVING_MIO', 'AWAY_PLAYERS_COUNT',
#        'AWAY_PLAYERS_AVG_AGE', 'AWAY_LEGIONARIES_COUNT',
#        'AWAY_AVG_MARKET_VALUE', 'AWAY_TOTAL_MARKET_VALUE',
#        'AWAY_AVG_AGE_JOINING', 'AWAY_AVG_AGE_LEAVING',
#        'AWAY_TOTAL_VALUE_JOINING_MIO', 'AWAY_TOTAL_VALUE_LEAVING_MIO',
#        'AWAY_EXPENSES_JOINING_MIO', 'AWAY_REVENUE_LEAVING_MIO'],
#       dtype='object')

# %%
df
# Out:
#            DATE  WEEKDAY  MONTH  SEASON  MATCHDAY                 HOME_TEAM  \
# 0    2004-08-06        4      8    2004         1          SV Werder Bremen
# 1    2004-08-07        5      8    2004         1       1.FC Kaiserslautern
# 2    2004-08-07        5      8    2004         1               SC Freiburg
# 3    2004-08-07        5      8    2004         1         Borussia Dortmund
# 4    2004-08-07        5      8    2004         1       Bayer 04 Leverkusen
# ...         ...      ...    ...     ...       ...                       ...
# 5809 2023-05-27        5      5    2022        34  Borussia Mönchengladbach
# 5810 2023-05-27        5      5    2022        34       Eintracht Frankfurt
# 5811 2023-05-27        5      5    2022        34             VfL Wolfsburg
# 5812 2023-05-27        5      5    2022        34                VfL Bochum
# 5813 2023-05-27        5      5    2022        34             VfB Stuttgart
#
#       PLACE_HOME_TEAM            AWAY_TEAM  PLACE_AWAY_TEAM  WIN_PERC_HOME  \
# 0                   3        FC Schalke 04                2            NaN
# 1                  12        1.FC Nürnberg               14            NaN
# 2                  18     FC Hansa Rostock               17            NaN
# 3                   7        VfL Wolfsburg                9            NaN
# 4                   6          Hannover 96               10            NaN
# ...               ...                  ...              ...            ...
# 5809               11          FC Augsburg               14           68.9
# 5810                8          SC Freiburg                5           31.4
# 5811                7           Hertha BSC               18           93.6
# 5812               16  Bayer 04 Leverkusen                6           13.0
# 5813               15  TSG 1899 Hoffenheim               13           70.9
#
#       ...  AWAY_PLAYERS_AVG_AGE  AWAY_LEGIONARIES_COUNT  \
# 0     ...                  25.6                      15
# 1     ...                  25.6                      12
# 2     ...                  27.5                      14
# 3     ...                  27.3                      18
# 4     ...                  26.1                      23
# ...   ...                   ...                     ...
# 5809  ...                  25.0                      23
# 5810  ...                  26.0                      11
# 5811  ...                  25.4                      21
# 5812  ...                  24.2                      24
# 5813  ...                  25.8                      21
#
#       AWAY_AVG_MARKET_VALUE  AWAY_TOTAL_MARKET_VALUE AWAY_AVG_AGE_JOINING  \
# 0                 2620000.0               86330000.0                 23.3
# 1                 1200000.0               34900000.0                 25.4
# 2                  925000.0               25900000.0                 26.1
# 3                 2120000.0               59300000.0                 25.2
# 4                 1230000.0               42980000.0                 25.1
# ...                     ...                      ...                  ...
# 5809              3150000.0              132280000.0                 22.6
# 5810              6930000.0              200950000.0                 23.3
# 5811              2290000.0               94000000.0                 23.7
# 5812             12930000.0              452550000.0                 21.8
# 5813              4830000.0              178800000.0                 23.9
#
#      AWAY_AVG_AGE_LEAVING  AWAY_TOTAL_VALUE_JOINING_MIO  \
# 0                    27.8                           NaN
# 1                    27.9                           NaN
# 2                    28.1                           NaN
# 3                    23.2                           NaN
# 4                    26.6                           NaN
# ...                   ...                           ...
# 5809                 24.6                         69.20
# 5810                 23.1                         59.75
# 5811                 24.4                         84.83
# 5812                 24.6                         55.85
# 5813                 25.0                         66.50
#
#       AWAY_TOTAL_VALUE_LEAVING_MIO  AWAY_EXPENSES_JOINING_MIO  \
# 0                              NaN                       4.65
# 1                              NaN                       2.25
# 2                              NaN                       0.55
# 3                              NaN                       8.50
# 4                              NaN                       1.88
# ...                            ...                        ...
# 5809                         39.50                      11.45
# 5810                         92.15                      15.90
# 5811                         80.78                       8.55
# 5812                         27.65                      15.10
# 5813                         84.50                      19.80
#
#       AWAY_REVENUE_LEAVING_MIO
# 0                         0.05
# 1                         0.15
# 2                         0.50
# 3                          NaN
# 4                         0.65
# ...                        ...
# 5809                      6.80
# 5810                     21.33
# 5811                     24.25
# 5812                      9.50
# 5813                     60.60
#
# [5814 rows x 38 columns]

# %%
print(df.dtypes)
# Out:
# DATE                            datetime64[ns]
# WEEKDAY                                  int64
# MONTH                                    int64
# SEASON                                   int32
# MATCHDAY                                 int64
# HOME_TEAM                               object
# PLACE_HOME_TEAM                          int64
# AWAY_TEAM                               object
# PLACE_AWAY_TEAM                          int64
# WIN_PERC_HOME                          float64
# REMIS_PERC                             float64
# WIN_PERC_AWAY                          float64
# HOME_GOALS                             float64
# AWAY_GOALS                             float64
# RESULT                                  object
# REFEREE                                 object
# HOME_PLAYERS_COUNT                       int64
# HOME_PLAYERS_AVG_AGE                   float64
# HOME_LEGIONARIES_COUNT                   int64
# HOME_AVG_MARKET_VALUE                  float64
# HOME_TOTAL_MARKET_VALUE                float64
# HOME_AVG_AGE_JOINING                   float64
# HOME_AVG_AGE_LEAVING                   float64
# HOME_TOTAL_VALUE_JOINING_MIO           float64
# HOME_TOTAL_VALUE_LEAVING_MIO           float64
# HOME_EXPENSES_JOINING_MIO              float64
# HOME_REVENUE_LEAVING_MIO               float64
# AWAY_PLAYERS_COUNT                       int64
# AWAY_PLAYERS_AVG_AGE                   float64
# AWAY_LEGIONARIES_COUNT                   int64
# AWAY_AVG_MARKET_VALUE                  float64
# AWAY_TOTAL_MARKET_VALUE                float64
# AWAY_AVG_AGE_JOINING                   float64
# AWAY_AVG_AGE_LEAVING                   float64
# AWAY_TOTAL_VALUE_JOINING_MIO           float64
# AWAY_TOTAL_VALUE_LEAVING_MIO           float64
# AWAY_EXPENSES_JOINING_MIO              float64
# AWAY_REVENUE_LEAVING_MIO               float64
# dtype: object

# %%
nan_count = df.isna().sum()
print(nan_count)
print(len(df))
# Out:
# DATE                               0
# WEEKDAY                            0
# MONTH                              0
# SEASON                             0
# MATCHDAY                           0
# HOME_TEAM                          0
# PLACE_HOME_TEAM                    0
# AWAY_TEAM                          0
# PLACE_AWAY_TEAM                    0
# WIN_PERC_HOME                   1530
# REMIS_PERC                      1530
# WIN_PERC_AWAY                   1530
# HOME_GOALS                         0
# AWAY_GOALS                         0
# RESULT                             0
# REFEREE                            0
# HOME_PLAYERS_COUNT                 0
# HOME_PLAYERS_AVG_AGE               0
# HOME_LEGIONARIES_COUNT             0
# HOME_AVG_MARKET_VALUE              0
# HOME_TOTAL_MARKET_VALUE            0
# HOME_AVG_AGE_JOINING               0
# HOME_AVG_AGE_LEAVING               0
# HOME_TOTAL_VALUE_JOINING_MIO     748
# HOME_TOTAL_VALUE_LEAVING_MIO    1224
# HOME_EXPENSES_JOINING_MIO         85
# HOME_REVENUE_LEAVING_MIO         272
# AWAY_PLAYERS_COUNT                 0
# AWAY_PLAYERS_AVG_AGE               0
# AWAY_LEGIONARIES_COUNT             0
# AWAY_AVG_MARKET_VALUE              0
# AWAY_TOTAL_MARKET_VALUE            0
# AWAY_AVG_AGE_JOINING               0
# AWAY_AVG_AGE_LEAVING               0
# AWAY_TOTAL_VALUE_JOINING_MIO     748
# AWAY_TOTAL_VALUE_LEAVING_MIO    1224
# AWAY_EXPENSES_JOINING_MIO         85
# AWAY_REVENUE_LEAVING_MIO         272
# dtype: int64
# 5814

# %%
df.describe()
# Out:
#                                 DATE      WEEKDAY        MONTH       SEASON  \
# count                           5814  5814.000000  5814.000000  5814.000000
# mean   2014-01-04 23:23:05.758514176     4.896801     6.531476  2013.000000
# min              2004-08-06 00:00:00     0.000000     1.000000  2004.000000
# 25%              2009-04-04 00:00:00     5.000000     3.000000  2008.000000
# 50%              2014-01-24 12:00:00     5.000000     5.000000  2013.000000
# 75%              2018-10-27 00:00:00     5.000000    10.000000  2018.000000
# max              2023-05-27 00:00:00     6.000000    12.000000  2022.000000
# std                              NaN     1.051085     3.712249     5.477697
#
#           MATCHDAY  PLACE_HOME_TEAM  PLACE_AWAY_TEAM  WIN_PERC_HOME  \
# count  5814.000000      5814.000000      5814.000000    4284.000000
# mean     17.500000         9.584451         9.415549      51.720985
# min       1.000000         1.000000         1.000000       0.200000
# 25%       9.000000         5.000000         5.000000      19.700000
# 50%      17.500000        10.000000         9.000000      54.100000
# 75%      26.000000        14.000000        14.000000      82.825000
# max      34.000000        18.000000        18.000000      99.600000
# std       9.811552         5.188682         5.187090      32.655442
#
#         REMIS_PERC  WIN_PERC_AWAY  ...  AWAY_PLAYERS_AVG_AGE  \
# count  4284.000000    4284.000000  ...           5814.000000
# mean     18.498366      29.781559  ...             25.240936
# min       0.200000       0.200000  ...             22.600000
# 25%       7.875000       4.700000  ...             24.700000
# 50%      18.200000      16.900000  ...             25.200000
# 75%      27.900000      51.800000  ...             25.800000
# max      53.500000      99.500000  ...             27.800000
# std      11.608141      30.106939  ...              0.913697
#
#        AWAY_LEGIONARIES_COUNT  AWAY_AVG_MARKET_VALUE  AWAY_TOTAL_MARKET_VALUE  \
# count             5814.000000           5.814000e+03             5.814000e+03
# mean                17.347953           4.496266e+06             1.521870e+08
# min                  2.000000           5.230000e+05             1.673000e+07
# 25%                 14.000000           1.860000e+06             6.060000e+07
# 50%                 17.000000           2.940000e+06             9.745000e+07
# 75%                 20.000000           5.170000e+06             1.763300e+08
# max                 29.000000           2.711000e+07             9.489500e+08
# std                  4.028607           4.471260e+06             1.546157e+08
#
#        AWAY_AVG_AGE_JOINING  AWAY_AVG_AGE_LEAVING  \
# count           5814.000000           5814.000000
# mean              23.162573             25.119883
# min               20.200000             20.800000
# 25%               22.200000             24.000000
# 50%               23.100000             24.900000
# 75%               24.100000             26.100000
# max               27.300000             30.100000
# std                1.334764              1.550105
#
#        AWAY_TOTAL_VALUE_JOINING_MIO  AWAY_TOTAL_VALUE_LEAVING_MIO  \
# count                   5066.000000                   4590.000000
# mean                      44.609849                     33.323333
# min                        0.050000                      0.025000
# 25%                        4.380000                      2.300000
# 50%                       26.050000                     15.505000
# 75%                       66.130000                     48.600000
# max                      361.850000                    258.200000
# std                       53.923845                     42.684517
#
#        AWAY_EXPENSES_JOINING_MIO  AWAY_REVENUE_LEAVING_MIO
# count                5729.000000               5542.000000
# mean                   21.848086                 18.915117
# min                     0.200000                  0.008000
# 25%                     4.650000                  3.400000
# 50%                    11.950000                  9.250000
# 75%                    27.100000                 22.680000
# max                   148.500000                270.950000
# std                    26.822624                 27.768590
#
# [8 rows x 34 columns]

# %% [markdown]
# ### Preparing the club-level data

# %%
# load data for clubs, transfers and final season tables
df_club = pd.read_pickle("./data/df_clubs_overview.pkl")
df_transfer = pd.read_pickle("./data/df_transfer_data.pkl")
df_final_table = pd.read_pickle("./data/df_final_table.pkl")
df_final_table = df_final_table[df_final_table['SEASON'].astype(int) >= 2004]
df_club_c = pd.merge(df_club, df_transfer, on=['CLUB_NAME', 'season'])
df_club_c = df_club_c[df_club_c['season'].astype(int) >= 2004]

# %%
def convert_market_value(value):
    try:
        # Entferne Kommas und ersetze sie durch Punkte
        value = value.replace(",", ".")
        
        # Millionen
        if "Mio. €" in value:
            value = value.replace("Mio. €", "")
            return float(value) * 1e6  # Multipliziere mit 1 Million

        # Tausend
        elif "Tsd. €" in value:
            value = value.replace("Tsd. €", "")
            return float(value) * 1e3  # Multipliziere mit 1 Tausend

        else:
            return None  # Falls die Konvertierung fehlschlägt, gebe None zurück

    except Exception as e:
        print(f"Konvertierungsfehler: {e}, Wert: {value}")
        return None  # Falls die Konvertierung fehlschlägt, gebe None zurück

# %%
# convert market value columns to decimals
df_club_c['AVG_MARKET_VALUE'] = df_club_c['AVG_MARKET_VALUE'].apply(convert_market_value)
df_club_c['TOTAL_MARKET_VALUE'] = df_club_c['TOTAL_MARKET_VALUE'].apply(convert_market_value)

# %%
columns_to_convert = df_club_c.drop(['CLUB_NAME'], axis=1).columns

for column in columns_to_convert:
    if df_club_c[column].dtype == 'object':  # Nur Spalten vom Typ 'object' verarbeiten
        df_club_c[column] = df_club_c[column].astype(str).str.replace(',', '.')
        df_club_c[column] = pd.to_numeric(df_club_c[column], errors='coerce')

# %%
columns_to_convert = df_final_table.drop(['CLUB_NAME'], axis=1).columns

for column in columns_to_convert:
    if df_final_table[column].dtype == 'object':  # Nur Spalten vom Typ 'object' verarbeiten
        df_final_table[column] = df_final_table[column].astype(str).str.replace(',', '.')
        df_final_table[column] = pd.to_numeric(df_final_table[column], errors='coerce')

# %%
club_mappings = {
   'Werder Bremen': 'SV Werder Bremen',
    "1.FC K'lautern": '1.FC Kaiserslautern',
    'SC Freiburg': 'SC Freiburg',
    'Bor. Dortmund': 'Borussia Dortmund',
    'B. Leverkusen': 'Bayer 04 Leverkusen',
    'Hertha BSC': 'Hertha BSC',
    'Hamburger SV': 'Hamburger SV',
    'Arm. Bielefeld': 'Arminia Bielefeld',
    'VfB Stuttgart': 'VfB Stuttgart',
    '1.FSV Mainz 05': '1.FSV Mainz 05',
    'Bayern München': 'FC Bayern München',
    "Bor. M'gladbach": 'Borussia Mönchengladbach',
    'Hansa Rostock': 'FC Hansa Rostock',
    'FC Schalke 04': 'FC Schalke 04',
    '1.FC Nürnberg': '1.FC Nürnberg',
    'VfL Bochum': 'VfL Bochum',
    'VfL Wolfsburg': 'VfL Wolfsburg',
    'Hannover 96': 'Hannover 96',
    'MSV Duisburg': 'MSV Duisburg',
    '1.FC Köln': '1.FC Köln',
    'E. Frankfurt': 'Eintracht Frankfurt',
    'Energie Cottbus': 'FC Energie Cottbus',
    'Alem. Aachen': 'Alemannia Aachen',
    'Karlsruher SC': 'Karlsruher SC',
    'TSG Hoffenheim': 'TSG 1899 Hoffenheim',
    'FC St. Pauli': 'FC St. Pauli',
    'FC Augsburg': 'FC Augsburg',
    'Greuther Fürth': 'SpVgg Greuther Fürth',
    'F. Düsseldorf': 'Fortuna Düsseldorf',
    'E. Braunschweig': 'Eintracht Braunschweig',
    'SC Paderborn': 'SC Paderborn 07',
    'Darmstadt 98': 'SV Darmstadt 98',
    'FC Ingolstadt': 'FC Ingolstadt 04',
    'RB Leipzig': 'RasenBallsport Leipzig',
    'Union Berlin': '1.FC Union Berlin'
}

# %%
# rename clubs to match between all datasets
df_final_table['CLUB_NAME'] = df_final_table['CLUB_NAME'].replace(club_mappings)

# %%
df_club_c = df_final_table.merge(df_club_c, left_on=['CLUB_NAME', 'SEASON'], right_on=['CLUB_NAME', 'season'], how="left").drop("season", axis=1)

# %%
df_club_c
# Out:
#      SEASON          CLUB_NAME  PLACE  PLAYERS_COUNT  PLAYERS_AVG_AGE  \
# 0      2004  FC Bayern München      1             29             27.6
# 1      2004      FC Schalke 04      2             33             25.6
# 2      2004   SV Werder Bremen      3             29             25.0
# 3      2004         Hertha BSC      4             30             26.3
# 4      2004      VfB Stuttgart      5             31             25.5
# ..      ...                ...    ...            ...              ...
# 337    2022         VfL Bochum     14             32             27.7
# 338    2022        FC Augsburg     15             42             25.0
# 339    2022      VfB Stuttgart     16             39             23.2
# 340    2022      FC Schalke 04     17             43             26.4
# 341    2022         Hertha BSC     18             41             25.4
#
#      LEGIONARIES_COUNT  AVG_MARKET_VALUE  TOTAL_MARKET_VALUE  AVG_AGE_JOINING  \
# 0                   14         6040000.0         175300000.0             26.2
# 1                   15         2620000.0          86330000.0             23.3
# 2                   14         3400000.0          98480000.0             24.8
# 3                   14         2390000.0          71780000.0             22.8
# 4                   14         2560000.0          79500000.0             23.7
# ..                 ...               ...                 ...              ...
# 337                 18         1680000.0          53700000.0             25.4
# 338                 23         3150000.0         132280000.0             22.6
# 339                 21         3870000.0         151050000.0             22.8
# 340                 22         2040000.0          87780000.0             24.7
# 341                 21         2290000.0          94000000.0             23.7
#
#      AVG_AGE_LEAVING  TOTAL_VALUE_JOINING_MIO  TOTAL_VALUE_LEAVING_MIO  \
# 0               24.3                    0.150                      NaN
# 1               27.8                      NaN                      NaN
# 2               26.4                      NaN                      NaN
# 3               24.5                    0.075                      NaN
# 4               23.6                      NaN                      NaN
# ..               ...                      ...                      ...
# 337             26.0                   26.800                    39.48
# 338             24.6                   69.200                    39.50
# 339             22.8                   72.750                    99.90
# 340             24.6                   90.150                    89.85
# 341             24.4                   84.830                    80.78
#
#      EXPENSES_JOINING_MIO  REVENUE_LEAVING_MIO
# 0                   25.75                 1.03
# 1                    4.65                 0.05
# 2                    9.00                 6.45
# 3                    2.55                 1.28
# 4                    2.15                 4.25
# ..                    ...                  ...
# 337                  1.79                16.05
# 338                 11.45                 6.80
# 339                 14.99                52.60
# 340                  8.63                21.35
# 341                  8.55                24.25
#
# [342 rows x 14 columns]

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# First, analyzing potential correlations between columns with a scatterplot matrix as an entrypoint.

# %%
sns.set(style="ticks")
pairplot = sns.pairplot(df_club_c.drop("SEASON", axis=1))

plt.subplots_adjust(top=0.95)  # Adjust the position of the title
pairplot.fig.suptitle("Scatterplot -Matrix: verschiedene Vereinseigenschaften", fontsize=16)
plt.savefig("./plots/scatter_matrix.svg", format="svg")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Luca\miniconda3\envs\web-mining\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Luca\AppData\Local\Temp\ipykernel_944\4110822200.py:7: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
sns.set(style="ticks")
scatter = sns.scatterplot(data=df_club_c, x="TOTAL_MARKET_VALUE", y="PLACE")

plt.subplots_adjust(top=0.9)  # Adjust the position of the title
plt.title("Scatterplot: Bundesliga-Platzierung vs. Gesamtmarktwert")
plt.show()

# %%
market_value_per_season = df_club_c.groupby("SEASON")["TOTAL_MARKET_VALUE"].sum()

# %%
from matplotlib.ticker import MaxNLocator
plt.figure(figsize=(10, 6))

plt.plot(market_value_per_season.index, market_value_per_season.values, marker='o', linestyle='-')
plt.title('Bundesliga-Gesamtmarktwert je Saison')
plt.xlabel('Saison')
plt.ylabel('Marktwert in Milliarden Euro')

ax = plt.gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.grid(True)
#plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
legioniaries_per_season = df_club_c.groupby("SEASON")["LEGIONARIES_COUNT"].sum()

# %%
plt.figure(figsize=(10, 6))

plt.plot(legioniaries_per_season.index, legioniaries_per_season.values, marker='o', linestyle='-')
plt.title('Legionäre in der Bundesliga nach Saison')
plt.xlabel('Saison')
plt.ylabel('Anzahl Legionäre')

ax = plt.gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.grid(True)
#plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
players_per_club_per_season = df_club_c.groupby("SEASON")["PLAYERS_COUNT"].mean()

# %%
plt.figure(figsize=(10, 6)) 

plt.plot(players_per_club_per_season.index, players_per_club_per_season.values, marker='o', linestyle='-')
plt.title('Anzahl Spieler pro Verein je Saison Saison')
plt.xlabel('Saison')
plt.ylabel('Anzahl Spieler')

ax = plt.gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.grid(True)
#plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
avg_age_season = df_club_c.groupby("SEASON")["PLAYERS_AVG_AGE"].mean()
avg_age_joining_season = df_club_c.groupby("SEASON")["AVG_AGE_JOINING"].mean()
avg_age_leaving_season = df_club_c.groupby("SEASON")["AVG_AGE_LEAVING"].mean()

# %%
plt.figure(figsize=(10, 6))

plt.plot(avg_age_season.index, avg_age_season.values, marker='o', linestyle='-', label='Durchschnittsalter')
plt.plot(avg_age_joining_season.index, avg_age_joining_season.values, marker='o', linestyle='-', label='Durchschnittsalter Zugänge')
plt.plot(avg_age_leaving_season.index, avg_age_leaving_season.values, marker='o', linestyle='-', label='Durchschnittsalter Abgänge')
plt.title('Durchschnittsalter von Zu- und Abgängen je Saison')
plt.xlabel('Saison')
plt.ylabel('Alter in Jahren')

ax = plt.gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.grid(True)
plt.legend()
#plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
expenses_joining_season = df_club_c.groupby("SEASON")["EXPENSES_JOINING_MIO"].mean()
revenue_leaving_season = df_club_c.groupby("SEASON")["REVENUE_LEAVING_MIO"].mean()

# %%
plt.figure(figsize=(10, 6))

plt.plot(expenses_joining_season.index, expenses_joining_season.values, marker='o', linestyle='-', label='Durchschnittliche Ausgaben')
plt.plot(revenue_leaving_season.index, revenue_leaving_season.values, marker='o', linestyle='-', label='Durchschnittliche Einnahmen')
plt.title('Durchschnittliche Einnahmen und Ausgaben')
plt.xlabel('Saison')
plt.ylabel('Millionen Euro')

ax = plt.gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.grid(True)
plt.legend()
#plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Matchday data

# %%
df_matches = pd.read_pickle("./data/df_matchday_data.pkl")
df_matches = df_matches[df_matches["SEASON"] >= 2004]

# %%
avg_home_goals = df_matches.groupby("SEASON")["HOME_GOALS"].mean()
avg_away_goals = df_matches.groupby("SEASON")["AWAY_GOALS"].mean()

# %%
plt.figure(figsize=(10, 6))

plt.plot(avg_home_goals.index, avg_home_goals.values, marker='o', linestyle='-', label='Durchschnittliche Anzahl Heimtore')
plt.plot(avg_away_goals.index, avg_away_goals.values, marker='o', linestyle='-', label='Durchschnittliche Anzahl Auswärtstore')
plt.title('Durchschnittliche Anzahl Heim- und Auswärtstore')
plt.xlabel('Saison')
plt.ylabel('Anzahl Tore')

ax = plt.gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.grid(True)
plt.legend()
#plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
result_per_season = df_matches.groupby("SEASON")["RESULT"].value_counts().to_frame().reset_index()
home_win_per_season = result_per_season[result_per_season["RESULT"] == "HOME_WIN"]
away_win_per_season = result_per_season[result_per_season["RESULT"] == "AWAY_WIN"]
draw_per_season = result_per_season[result_per_season["RESULT"] == "DRAW"]

# %%
plt.figure(figsize=(10, 6))

plt.plot(home_win_per_season.index, home_win_per_season["count"].values, marker='o', linestyle='-', label='Anzahl Heimsiege')
plt.plot(away_win_per_season.index, away_win_per_season["count"].values, marker='o', linestyle='-', label='Anzahl Auswärtssiege')
plt.plot(draw_per_season.index, draw_per_season["count"].values, marker='o', linestyle='-', label='Anzahl Unentschieden')
plt.title('Anzahl der verschiedenen Spielausgänge je Saison')
plt.xlabel('Saison')
plt.ylabel('Anzahl')

ax = plt.gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.grid(True)
plt.legend()
#plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Analyzing the relation between tip round results and actual results

# %%
df_perc = df_matches.dropna(subset=["WIN_PERC_HOME", "WIN_PERC_AWAY", "REMIS_PERC"])

# %%
def get_expected_result(row):
    """Based on the percentages given, return whether the users expect the home team to win, a draw or a win of the away team"""
    win_perc_home, win_perc_away, remis_perc = row
    max_value = max(win_perc_home, win_perc_away, remis_perc)

    # Determine the corresponding result
    if max_value == win_perc_home:
        return 'HOME_WIN'
    elif max_value == win_perc_away:
        return 'AWAY_WIN'
    else:
        return 'DRAW'

# %%
df_perc.loc[:, "EXPECTED_RESULT"] = df_perc[["WIN_PERC_HOME", "WIN_PERC_AWAY", "REMIS_PERC"]].copy().apply(get_expected_result, axis=1)
# Out:
# C:\Users\Luca\AppData\Local\Temp\ipykernel_944\3519350741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_perc.loc[:, "EXPECTED_RESULT"] = df_perc[["WIN_PERC_HOME", "WIN_PERC_AWAY", "REMIS_PERC"]].copy().apply(get_expected_result, axis=1)

# %%
from sklearn.metrics import accuracy_score, balanced_accuracy_score

# %%
accuracy_score(df_perc["RESULT"], df_perc["EXPECTED_RESULT"])
# Out:
# 0.5060690943043884

# %%
balanced_accuracy_score(df_perc["RESULT"], df_perc["EXPECTED_RESULT"])
# Out:
# 0.43732870244612326

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report, ConfusionMatrixDisplay

class_labels = ["HOME_WIN", "AWAY_WIN", "DRAW"]

# Create a confusion matrix
confusion = confusion_matrix(df_perc["RESULT"], df_perc["EXPECTED_RESULT"], labels=class_labels)
report = classification_report(df_perc["RESULT"], df_perc["EXPECTED_RESULT"])

print("\nClassification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#     AWAY_WIN       0.47      0.51      0.49      1307
#         DRAW       0.28      0.05      0.09      1050
#     HOME_WIN       0.54      0.75      0.63      1927
#
#     accuracy                           0.51      4284
#    macro avg       0.43      0.44      0.40      4284
# weighted avg       0.45      0.51      0.45      4284

# %%
# Plot the confusion matrix
disp = ConfusionMatrixDisplay(confusion, display_labels=class_labels)
disp.plot(cmap='Blues', values_format='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### Analyzing the influence of referees on the match result
# pro Schiedsrichter die Gewinnwahrscheinlichkeit der einzelnen Mannschaften
# = Anzahl Siege pro Schiedsrichter pro Team / Anzahl Spiele pro Schiedsrichter pro Team

# %%
df_matches
# Out:
#          DATE  WEEKDAY  MONTH  SEASON  MATCHDAY        HOME_TEAM  \
# 0  2004-08-06        4      8    2004         1    Werder Bremen
# 1  2004-08-07        5      8    2004         1   1.FC K'lautern
# 2  2004-08-07        5      8    2004         1      SC Freiburg
# 3  2004-08-07        5      8    2004         1    Bor. Dortmund
# 4  2004-08-07        5      8    2004         1    B. Leverkusen
# ..        ...      ...    ...     ...       ...              ...
# 4  2023-05-27        5      5    2022        34  Bor. M'gladbach
# 5  2023-05-27        5      5    2022        34     E. Frankfurt
# 6  2023-05-27        5      5    2022        34    VfL Wolfsburg
# 7  2023-05-27        5      5    2022        34       VfL Bochum
# 8  2023-05-27        5      5    2022        34    VfB Stuttgart
#
#    PLACE_HOME_TEAM       AWAY_TEAM PLACE_AWAY_TEAM  WIN_PERC_HOME  REMIS_PERC  \
# 0                3   FC Schalke 04               2            NaN         NaN
# 1               12   1.FC Nürnberg              14            NaN         NaN
# 2               18   Hansa Rostock              17            NaN         NaN
# 3                7   VfL Wolfsburg               9            NaN         NaN
# 4                6     Hannover 96              10            NaN         NaN
# ..             ...             ...             ...            ...         ...
# 4               11     FC Augsburg              14           68.9        22.7
# 5                8     SC Freiburg               5           31.4        37.1
# 6                7      Hertha BSC              18           93.6         3.6
# 7               16   B. Leverkusen               6           13.0        16.5
# 8               15  TSG Hoffenheim              13           70.9        21.0
#
#     WIN_PERC_AWAY  HOME_GOALS  AWAY_GOALS    RESULT                  REFEREE
# 0             NaN         1.0         0.0  HOME_WIN         Stefan Trautmann
# 1             NaN         1.0         3.0  AWAY_WIN           Michael Weiner
# 2             NaN         0.0         0.0      DRAW     Dr. Helmut Fleischer
# 3             NaN         1.0         2.0  AWAY_WIN           Wolfgang Stark
# 4             NaN         2.0         1.0  HOME_WIN     Dr. Franz-Xaver Wack
# ..            ...         ...         ...       ...                      ...
# 4             8.3         2.0         0.0  HOME_WIN  Dr. Matthias Jöllenbeck
# 5            31.5         2.0         1.0  HOME_WIN            Deniz Aytekin
# 6             2.8         1.0         2.0  AWAY_WIN          Benjamin Cortus
# 7            70.5         3.0         0.0  HOME_WIN              Tobias Welz
# 8             8.0         1.0         1.0      DRAW          Robert Schröder
#
# [5814 rows x 16 columns]

# %%
def get_winning_team(row):
    """Based on the input, return the name of the team that won the game and the team that lost"""
    home_team, away_team, result = row
    if result == 'HOME_WIN':
        return home_team, away_team
    if result == 'AWAY_WIN':
        return away_team, home_team
    return 'DRAW', 'DRAW'

# %%
df_matches[["WINNER", "LOOSER"]] = df_matches[["HOME_TEAM", "AWAY_TEAM", "RESULT"]].apply(get_winning_team, axis=1).values.tolist()

# %%
df_ref = df_matches[df_matches["WINNER"] != "DRAW"]

# %%
wins_per_ref = df_ref.groupby(["REFEREE", "WINNER"]).size().reset_index()
wins_per_ref.columns = ["REFEREE", "WINNER", "WINS"]

# %%
# number of home games per referee and team
total_games_per_ref_home = df_ref.groupby(["REFEREE", "HOME_TEAM"]).size().reset_index()
total_games_per_ref_home.columns = ["REFEREE", "CLUB", "MATCHES"]
total_games_per_ref_home = total_games_per_ref_home.set_index(["REFEREE", "CLUB"])

# %%
# number of away games per referee and team
total_games_per_ref_away = df_ref.groupby(["REFEREE", "AWAY_TEAM"]).size().reset_index()
total_games_per_ref_away.columns = ["REFEREE", "CLUB", "MATCHES"]
total_games_per_ref_away = total_games_per_ref_away.set_index(["REFEREE", "CLUB"])

# %%
total_games_per_ref = (total_games_per_ref_home + total_games_per_ref_away).reset_index()
total_games_per_ref = total_games_per_ref.dropna(subset=["MATCHES"])

# %%
set(df_ref.HOME_TEAM.unique()) == set(df_ref.AWAY_TEAM.unique())
# Out:
# True

# %%
# calculate the win percentage for each team and each referee

res = []

for ref in df_ref.REFEREE.unique():
    for club in df_ref.HOME_TEAM.unique():
        num_games = total_games_per_ref[(total_games_per_ref["CLUB"] == club) & (total_games_per_ref["REFEREE"] == ref)]["MATCHES"].values
        if len(num_games) == 0:
            continue
        elif len(num_games) > 1:
            raise RuntimeError(f"More than one entry for {ref} and {club} for games!")
        num_games = num_games[0]
        wins = wins_per_ref[(wins_per_ref["WINNER"] == club) & (wins_per_ref["REFEREE"] == ref)]["WINS"].values
        if len(wins) == 0:
            continue
        elif len(wins) > 1:
            raise RuntimeError(f"More than one entry for {ref} and {club} for wins!")
        wins = wins[0]
        win_perc_for_ref = wins / num_games
        res.append((ref, club, num_games, wins, win_perc_for_ref))
        
df_win_perc = pd.DataFrame(res, columns=['REFEREE', 'CLUB', 'NUM_MATCHES', 'NUM_WINS', 'WIN_PERC'])

# %%
df_win_perc[df_win_perc["NUM_MATCHES"] >= 5]
# Out:
#                      REFEREE             CLUB  NUM_MATCHES  NUM_WINS  WIN_PERC
# 1             Michael Weiner    Werder Bremen         13.0         6  0.461538
# 2             Michael Weiner   1.FC K'lautern          6.0         2  0.333333
# 3             Michael Weiner    Bor. Dortmund         11.0        11  1.000000
# 4             Michael Weiner    B. Leverkusen         11.0         6  0.545455
# 5             Michael Weiner     Hamburger SV         10.0         5  0.500000
# ..                       ...              ...          ...       ...       ...
# 795       Florian Badstübner    Werder Bremen          5.0         2  0.400000
# 805       Florian Badstübner      FC Augsburg          5.0         2  0.400000
# 806       Florian Badstübner       RB Leipzig          6.0         6  1.000000
# 807       Florian Badstübner     Union Berlin          5.0         4  0.800000
# 810  Dr. Matthias Jöllenbeck  Bor. M'gladbach          5.0         3  0.600000
#
# [593 rows x 5 columns]

# %%
def barplot(df, target, x="REFEREE"):
    average_win_perc = df['WIN_PERC'].mean()
    plt.figure(figsize=(10, 6))
    ax = sns.barplot(data=df, x=x, y="WIN_PERC")
    ax.bar_label(ax.containers[0], fmt='%.2f')
    plt.axhline(y=average_win_perc, color='red', linestyle='--', label='Durchschnittliche Gewinnquote')
    plt.xticks(rotation=70)
    plt.title(f"Win percentage for {target}")
    plt.tight_layout()

    plt.show()

# %%
df_bayern = df_win_perc[(df_win_perc['CLUB'] == 'Bayern München') & (df_win_perc["NUM_MATCHES"] > 5)]
barplot(df_bayern, "Bayern München")

# %%
df_bayern = df_win_perc[(df_win_perc['CLUB'] == 'Bayern München') & (df_win_perc["NUM_MATCHES"] > 15)]
barplot(df_bayern, "Bayern München")

# %%
df_koeln = df_win_perc[(df_win_perc['CLUB'] == '1.FC Köln') & (df_win_perc["NUM_MATCHES"] > 10)]
barplot(df_koeln, "1. FC Köln")

# %%
df_koeln = df_win_perc[(df_win_perc['REFEREE'] == 'Sascha Stegemann') & (df_win_perc["NUM_MATCHES"] > 10)]
barplot(df_koeln, "Sascha Stegemann", x="CLUB")
