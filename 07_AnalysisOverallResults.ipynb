# %% [markdown]
# # Analysis of overall results

# %%
import helpers
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
result_path = './results'

# %%
df_total, _ = helpers.get_json_results_in_df(result_path)

# %%
print(df_total.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Total_Accuracy           6 non-null      float64
#  1   Total_Balanced_Accuracy  6 non-null      float64
#  2   Total_Precision_Class_0  6 non-null      float64
#  3   Total_Precision_Class_1  6 non-null      float64
#  4   Total_Precision_Class_2  6 non-null      float64
#  5   Total_Recall_Class_0     6 non-null      float64
#  6   Total_Recall_Class_1     6 non-null      float64
#  7   Total_Recall_Class_2     6 non-null      float64
#  8   Total_F1-Score_Class_0   6 non-null      float64
#  9   Total_F1-Score_Class_1   6 non-null      float64
#  10  Total_F1-Score_Class_2   6 non-null      float64
#  11  Model                    6 non-null      object
# dtypes: float64(11), object(1)
# memory usage: 704.0+ bytes
# None

# %%
helpers.plot_sorted_vertical_bar(df_total, 'Total_Accuracy')

# %%
helpers.plot_sorted_vertical_bar(df_total, 'Total_Balanced_Accuracy')

# %%
helpers.plot_sorted_vertical_bar(df_total, 'Total_Precision_Class_0')

# %%
helpers.plot_sorted_vertical_bar(df_total, 'Total_Precision_Class_1')

# %%
helpers.plot_sorted_vertical_bar(df_total, 'Total_Precision_Class_2')

# %%
helpers.plot_sorted_vertical_bar(df_total, 'Total_Recall_Class_0')

# %%
helpers.plot_sorted_vertical_bar(df_total, 'Total_Recall_Class_1')

# %%
helpers.plot_sorted_vertical_bar(df_total, 'Total_Recall_Class_2')

# %%
helpers.plot_sorted_vertical_bar(df_total, 'Total_F1-Score_Class_0')

# %%
helpers.plot_sorted_vertical_bar(df_total, 'Total_F1-Score_Class_1')

# %%
helpers.plot_sorted_vertical_bar(df_total, 'Total_F1-Score_Class_2')
