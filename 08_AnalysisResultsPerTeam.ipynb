# %% [markdown]
# # Analysis of results per team

# %%
import helpers
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
result_path = './results'
SHOW_TOP_X_CLUBS = 7

# %%
_, df_clubs = helpers.get_json_results_in_df(result_path)

# %%
print(df_clubs.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 36 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   home_games              130 non-null    int64
#  1   home_games_win          130 non-null    int64
#  2   home_games_draw         130 non-null    int64
#  3   home_games_loss         130 non-null    int64
#  4   home_accuracy           130 non-null    float64
#  5   home_balanced_accuracy  130 non-null    float64
#  6   home_precision_class_0  130 non-null    float64
#  7   home_precision_class_1  130 non-null    float64
#  8   home_precision_class_2  130 non-null    float64
#  9   home_recall_class_0     130 non-null    float64
#  10  home_recall_class_1     130 non-null    float64
#  11  home_recall_class_2     130 non-null    float64
#  12  home_f1-score_class_0   130 non-null    float64
#  13  home_f1-score_class_1   130 non-null    float64
# ...

# %%
helpers.plot_best_model_per_club(df_clubs, 'home_accuracy', top_x=SHOW_TOP_X_CLUBS, game_columns='home_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'home_balanced_accuracy', top_x=SHOW_TOP_X_CLUBS, game_columns='home_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'home_precision_class_0', top_x=SHOW_TOP_X_CLUBS, game_columns='home_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'home_precision_class_1', top_x=SHOW_TOP_X_CLUBS, game_columns='home_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'home_precision_class_2', top_x=SHOW_TOP_X_CLUBS, game_columns='home_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'home_recall_class_0', top_x=SHOW_TOP_X_CLUBS, game_columns='home_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'home_recall_class_1', top_x=SHOW_TOP_X_CLUBS, game_columns='home_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'home_recall_class_2', top_x=SHOW_TOP_X_CLUBS, game_columns='home_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'home_f1-score_class_0', top_x=SHOW_TOP_X_CLUBS, game_columns='home_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'home_f1-score_class_1', top_x=SHOW_TOP_X_CLUBS, game_columns='home_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'home_f1-score_class_2', top_x=SHOW_TOP_X_CLUBS, game_columns='home_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'away_accuracy', top_x=SHOW_TOP_X_CLUBS, game_columns='away_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'away_balanced_accuracy', top_x=SHOW_TOP_X_CLUBS, game_columns='away_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'away_precision_class_0', top_x=SHOW_TOP_X_CLUBS, game_columns='away_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'away_precision_class_1', top_x=SHOW_TOP_X_CLUBS, game_columns='away_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'away_precision_class_2', top_x=SHOW_TOP_X_CLUBS, game_columns='away_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'away_recall_class_0', top_x=SHOW_TOP_X_CLUBS, game_columns='away_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'away_recall_class_1', top_x=SHOW_TOP_X_CLUBS, game_columns='away_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'away_recall_class_2', top_x=SHOW_TOP_X_CLUBS, game_columns='away_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'away_f1-score_class_0', top_x=SHOW_TOP_X_CLUBS, game_columns='away_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'away_f1-score_class_1', top_x=SHOW_TOP_X_CLUBS, game_columns='away_games')

# %%
helpers.plot_best_model_per_club(df_clubs, 'away_f1-score_class_2', top_x=SHOW_TOP_X_CLUBS, game_columns='away_games')
